# %% [markdown]
# ## Quantum Sand Project Template PyTorch 001
#
# ### Import dependencies
#
# We will import `torch` and `numpy`

# %%
import torch

# %%
import numpy as np

# %%
torch.__version__

# %% [markdown]
# ### macOS only
#
# Test accelerated PyTorch training on macOS; PyTorch uses the Metal Performance Shaders (MPS) backend for GPU acceleration.

# %%
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
